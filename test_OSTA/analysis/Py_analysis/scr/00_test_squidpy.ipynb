# %%
import squidpy as sq

# %%
print(f"squidpy=={sq.__version__}")

adata = sq.datasets.visium_hne_adata()
img = sq.datasets.visium_hne_image()
# Out:
# squidpy==1.2.2
# /home/edo/micromamba/envs/env_squidpy122/lib/python3.9/site-packages/squidpy/im/_container.py:1371: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   return self.data.dims["y"], self.data.dims["x"]

# %%
print(adata)
print(adata.obs.head())
sq.pl.spatial_scatter(adata, color="in_tissue", alpha=0.7)
# Out:
# AnnData object with n_obs × n_vars = 2688 × 18078
#     obs: 'in_tissue', 'array_row', 'array_col', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_500_genes', 'total_counts_mt', 'log1p_total_counts_mt', 'pct_counts_mt', 'n_counts', 'leiden', 'cluster'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'cluster_colors', 'hvg', 'leiden', 'leiden_colors', 'neighbors', 'pca', 'rank_genes_groups', 'spatial', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'
#                     in_tissue  array_row  array_col  n_genes_by_counts  \
# ...

# %%
# sample read in image from spaceranger output
# Define the path to the image file
image_path = "../../../data/ /output/spatial/tissue_hires_image.png"

# Load the image using Squidpy's ImageContainer
img = sq.im.ImageContainer(image_path)

# Display the image
img.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 6
#       3 image_path = "../../../data/ /output/spatial/tissue_hires_image.png"
#       5 # Load the image using Squidpy's ImageContainer
# ----> 6 img = sq.im.ImageContainer(image_path)
#       8 # Display the image
#       9 img.show()
#
# File ~/micromamba/envs/env_squidpy122/lib/python3.9/site-packages/squidpy/im/_container.py:113, in ImageContainer.__init__(self, img, layer, lazy, scale, **kwargs)
#     110 self._data.attrs[Key.img.mask_circle] = False
#     112 if img is not None:
# --> 113     self.add_img(img, layer=layer, **kwargs)
#     114     if not lazy:
#     115         self.compute()
#
# File ~/micromamba/envs/env_squidpy122/lib/python3.9/site-packages/squidpy/im/_container.py:288, in ImageContainer.add_img(self, img, layer, dims, library_id, lazy, chunks, copy, **kwargs)
# ...

# %%
# sample load all the spatial data
# import squidpy as sq

# Define the path to the SpaceRanger output
data_path = "/path/to/spaceranger/output/"

# Load both AnnData and spatial image using Squidpy
adata = sq.datasets.visium(path=data_path)

# Check the data structure
print(adata)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 8
#       5 data_path = "/path/to/spaceranger/output/"
#       7 # Load both AnnData and spatial image using Squidpy
# ----> 8 adata = sq.datasets.visium(path=data_path)
#      10 # Check the data structure
#      11 print(adata)
#
# TypeError: visium() got an unexpected keyword argument 'path'

# %%
img
# Out:
# /home/edo/micromamba/envs/env_squidpy122/lib/python3.9/site-packages/squidpy/im/_container.py:1371: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   return self.data.dims["y"], self.data.dims["x"]
# ImageContainer[shape=(11757, 11291), layers=['image']]

# %%
img.interactive(adata)
# Out:
# /home/edo/micromamba/envs/env_squidpy122/lib/python3.9/site-packages/squidpy/im/_container.py:1371: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   return self.data.dims["y"], self.data.dims["x"]
# Interactive view of ImageContainer[shape=(11757, 11291), layers=['image']]
